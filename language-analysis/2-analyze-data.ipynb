# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/language.csv')
df.head()
#soup = BeautifulSoup(page.content, 'html.parser')
# Out:
#           Country                                          Languages
# 0     Afghanistan            \n        Afghan Persian or Dari (of...
# 1        Akrotiri            \n        English, Greek\n        \n...
# 2         Albania            \n        Albanian 98.8% (official -...
# 3         Algeria            \n        Arabic  (official), French...
# 4  American Samoa            \n        Samoan 88.6% (closely rela...

# %%
table.iloc[0, 1]
# Out:
# '          \n        Afghan Persian or Dari (official) 77% (Dari functions as the lingua franca), Pashto (official) 48%, Uzbek 11%, English 6%, Turkmen 3%, Urdu 3%, Pashayi 1%, Nuristani 1%, Arabic 1%, Balochi 1%\n        (2017 est.)\n\n\nnote: data represent most widely spoken languages; shares sum to more than 100% because there is much bilingualism in the country and because respondents were allowed to select more than one language\nnote: the Turkic languages Uzbek and Turkmen, as well as Balochi, Pashayi, Nuristani, and Pamiri are the third official languages in areas where the majority speaks them'

# %% [markdown]
# Find if country uses these language:
# + English
# + Spanish
# + French
# + Portugese
# + Chinese
# + Hindi

# %%
# Grab language to match 

# Create columns
df = table.copy()

df['English'] = False
df['Spanish'] = False
df['French'] = False
df['Portuguese'] = False
df['Chinese'] = False
df['Hindi'] = False
df['Arabic'] = False

# %%
df.sample(5)
# Out:
#                     Country  \
# 212                Thailand
# 164                   Palau
# 26   Bosnia and Herzegovina
# 146                 Morocco
# 88                     Guam
#
#                                              Languages  English  Spanish  \
# 212            \n        Thai (official) only 90.7%...    False    False
# 164            \n        Palauan (official on most ...    False    False
# 26             \n        Bosnian (official) 52.9%, ...    False    False
# 146            \n        Arabic (official), Berber ...    False    False
# 88             \n        English 43.6%, Filipino 21...    False    False
#
#      French  Portuguese  Chinese  Hindi  Arabic
# 212   False       False    False  False   False
# 164   False       False    False  False   False
# 26    False       False    False  False   False
# 146   False       False    False  False   False
# 88    False       False    False  False   False

# %%
df
# Out:
#             Country                                          Languages  \
# 0       Afghanistan            \n        Afghan Persian or Dari (of...
# 1          Akrotiri            \n        English, Greek\n        \n...
# 2           Albania            \n        Albanian 98.8% (official -...
# 3           Algeria            \n        Arabic  (official), French...
# 4    American Samoa            \n        Samoan 88.6% (closely rela...
# ..              ...                                                ...
# 235       West Bank            \n        Arabic, Hebrew  (spoken by...
# 236  Western Sahara            \n        Standard Arabic, Hassaniya...
# 238           Yemen            \n        Arabic (official)\n       ...
# 239          Zambia            \n        Bemba 33.4%, Nyanja 14.7%,...
# 240        Zimbabwe            \n        Shona  (official; most wid...
#
#      English  Spanish  French  Portuguese  Chinese  Hindi  Arabic
# ...

# %%
# Put languages in a list for the below "for" loop 
lange_names = list(df.iloc[:, 2:].columns)

# Boolean values for country which has the language name appears in the description
for col in lange_names:
    for row in range(len(df)):
        df[col][row] = (col in df.Languages[row])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-180-0359f1faa550> in <module>()
#       5 for col in lange_names:
#       6     for row in range(len(df)):
# ----> 7         df[col][row] = (col in df.Languages[row])
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
# ...

# %%
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df
# Out:
#             Country                                          Languages  \
# 0       Afghanistan            \n        Afghan Persian or Dari (of...
# 1          Akrotiri            \n        English, Greek\n        \n...
# 2           Albania            \n        Albanian 98.8% (official -...
# 3           Algeria            \n        Arabic  (official), French...
# 4    American Samoa            \n        Samoan 88.6% (closely rela...
# ..              ...                                                ...
# 236  Western Sahara            \n        Standard Arabic, Hassaniya...
# 237           World  most-spoken language:Â English 16.5%, Mandarin...
# 238           Yemen            \n        Arabic (official)\n       ...
# 239          Zambia            \n        Bemba 33.4%, Nyanja 14.7%,...
# 240        Zimbabwe            \n        Shona  (official; most wid...
#
#      English  Spanish  French  Portuguese  Chinese  Hindi  Arabic
# ...

# %%
df.describe()
# Out:
#               Country                                          Languages  \
# count             241                                                241
# unique            241                                                232
# top     Cote d'Ivoire            \n        Spanish (official)\n      ...
# freq                1                                                  4
#
#        English Spanish French Portuguese Chinese  Hindi Arabic
# count      241     241    241        241     241    241    241
# unique       2       2      2          2       2      2      2
# top       True   False  False      False   False  False  False
# freq       141     203    173        218     223    234    202

# %%
lange_names
# Out:
# ['English', 'Spanish', 'French', 'Portuguese', 'Chinese', 'Hindi', 'Arabic']

# %%
df = df.drop('Languages', axis = 1)

# %%
df = df.melt(id_vars = 'Country', var_name = 'Language')

# %%
df.groupby('Language').sum().sort_values('value', ascending = False)
# Out:
#             value
# Language
# English     141.0
# French       68.0
# Arabic       39.0
# Spanish      38.0
# Portuguese   23.0
# Chinese      18.0
# Hindi         7.0

# %%
df
# Out:
#             Country  English  Spanish  French  Portuguese  Chinese  Hindi  \
# 0       Afghanistan     True    False   False       False    False  False
# 1          Akrotiri     True    False   False       False    False  False
# 2           Albania    False    False   False       False    False  False
# 3           Algeria    False    False    True       False    False  False
# 4    American Samoa     True    False   False       False    False  False
# ..              ...      ...      ...     ...         ...      ...    ...
# 236  Western Sahara    False     True    True       False    False  False
# 237           World     True     True    True        True     True   True
# 238           Yemen    False    False   False       False    False  False
# 239          Zambia     True    False   False       False    False  False
# 240        Zimbabwe     True    False   False       False    False  False
#
#      Arabic
# 0      True
# 1     False
# 2     False
# 3      True
# ...
